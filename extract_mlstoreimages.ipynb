# %%
import requests
import json

from dotenv import load_dotenv
import os
from shutil import copy
from pathlib import Path
from shutil import copy
import asyncio
import io
import aiohttp
from typing import List
from PIL import Image, ImageOps

import nest_asyncio
nest_asyncio.apply()

# %%
async def fetch_image(session, url):
    async with session.get(url) as response:
        img_bytes = await response.read()
        return img_bytes


async def download_images(image_urls: List[str],filenames,output_path) -> List[Image.Image]:
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_image(session, url) for url in image_urls]
        images_bytes = await asyncio.gather(*tasks)
    
    print("Collected images' bytes!")
    images = []
    
    for image_bytes,filename in zip(images_bytes,filenames):
        
        img = ImageOps.exif_transpose(Image.open(io.BytesIO(image_bytes)).convert("RGB"))
        images.append(img)
        filename = filename.lower()
        filename = Path(filename + ".jpg")
        img.save(output_path/filename)
    
    return images

# %%
load_dotenv()

username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")

# %%
# store folders that have cereal boxes

dirs = ["/Users/iman/Downloads/ml-store-images/bf71326f-5168-48d9-9cd3-f7f5c32cd94c",
"/Users/iman/Downloads/ml-store-images/33eeaf0b-47da-4350-b8c6-ca499684da56",
"/Users/iman/Downloads/ml-store-images/59d021de-d665-443d-9ce5-5ba6d6a7e1c0",
"/Users/iman/Downloads/ml-store-images/160334d6-a310-4429-b460-c26e19de203e",
"/Users/iman/Downloads/ml-store-images/1830657b-f07a-4fee-8879-274113a9d7b7",
"/Users/iman/Downloads/ml-store-images/d910cc27-35a7-49e5-9c76-f0083f0e9345",
"/Users/iman/Downloads/ml-store-images/d428b039-9a8d-4e50-bae4-5a62596ba0bb",
"/Users/iman/Downloads/ml-store-images/b2b31caf-9e2b-4d73-bc5d-28890cb0d976",
"/Users/iman/Downloads/ml-store-images/1e0097c9-55f5-4667-8ad8-f00b5c715ea7",
"/Users/iman/Downloads/ml-store-images/7a31d692-8a0d-42b3-96f4-c81613ed0477",
"/Users/iman/Downloads/ml-store-images/eca17d09-9deb-45b6-88de-36b4f3fb83df",
"/Users/iman/Downloads/ml-store-images/57505c09-0472-4c75-90c5-e0e59986e088"]

stores = [store.split("/")[-1] for store in dirs]

# %%
training_dir = Path("/Users/iman/ml-datasets/detection_boxes/training_data")

# %%
# training_dir = Path("/Users/iman/ml-datasets/detection_boxes/training_data")
# for directory in dirs:
#     directory = Path(directory)
#     for img in directory.glob('*.jpg'):
#         if "stitched_image" not in img.name:
#             copy(img,training_dir / img.name)

# %%
login_url = "https://api.345.global/api/v1/login/access-token"
credentials = {"username": username, "password": password,"grant_type": "password"}
response = requests.post(login_url, data=credentials)
token_response = response.json()

# %%
training_images_paths = [path.name for path in (training_dir / "all_images").glob("*.jpg")]

# %%
### query ml_store_images API endpoint and download all images

from PIL import Image
#access_token = token_response["access_token"]
token_type = token_response.get("token_type", "Bearer") 
token = token_response.get("access_token", None)

# 2. Set headers
headers = {
    "Authorization": f"{token_type} {token}"
}

uuids_filter = ""
from urllib.parse import quote
annotations = []
images_api = set()
for store in stores:
    url = f"https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&store={store}"
    response = requests.get(url, headers=headers)
    response_data = response.json()
    store_images = response_data["data"]
    os.makedirs(training_dir / store,exist_ok=True)
    image_urls = [image["url"] for image in store_images if image["annotations"] != []]
    image_filenames = [image["uuid"] for image in store_images if image["annotations"] != []]
    asyncio.run(download_images(image_urls, image_filenames, training_dir / store))
# Out:
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!

# %%
good_uuids = [img.stem for img in Path("/Users/iman/ml-datasets/detection_boxes/drawn_bboxes/very good").glob("*.jpg")]
change_anno_uuids = [img.stem for img in Path("/Users/iman/ml-datasets/detection_boxes/drawn_bboxes/update_annotations").glob("*.jpg")]

# %%
### create MLA files from images sorted into subdirs

#access_token = token_response["access_token"]
token_type = token_response.get("token_type", "Bearer") 
token = token_response.get("access_token", None)

# 2. Set headers
headers = {
    "Authorization": f"{token_type} {token}"
}

uuids_filter = ""
from urllib.parse import quote
annotations = []
images_api = set()
for store in stores:
    url = f"https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&store={store}"
    response = requests.get(url, headers=headers)
    response_data = response.json()
    store_images = response_data["data"]
    for image in store_images:
        # if os.path.exists():
        #print(image["annotations"] == [])
        if image["annotations"] == []:
            continue
        if image["uuid"] in good_uuids:
            output_path = (Path("/Users/iman/ml-datasets/detection_boxes/mla_files/very_good") / image["uuid"]).with_suffix(".mla")    
            with open(output_path,"w") as f:
                json.dump(image,f)  
        elif image["uuid"] in change_anno_uuids:
            output_path = (Path("/Users/iman/ml-datasets/detection_boxes/mla_files/update_annotations") / image["uuid"]).with_suffix(".mla")    
            with open(output_path,"w") as f:
                json.dump(image,f)

# %%
all_images = []
for store in training_dir.iterdir():
    if store.is_dir():
        for img in store.glob("*.jpg"):
            if img.name != ".DS_Store":
                all_images.append(img)

len(set(all_images))
# Out:
# 684

# %%
from torchvision import transforms
from torchvision.utils import draw_bounding_boxes, save_image
import torch
to_tensor = transforms.ToTensor()
for image_path in tqdm(training_dir.rglob("*.jpg")):
    image = to_tensor(Image.open(image_path).convert("RGB"))
    boxes = [annotation for annotation in annotations if annotation["uuid"] == image_path.stem][0]["bounding_boxes"]
    bboxes = []
    for i, box in enumerate(boxes):
        # if not box["face"]:
        #     continue
        bboxes.append([box["xmin"], box["ymin"], box["xmax"], box["ymax"]])
    bboxes = torch.tensor(bboxes, dtype=torch.float32).reshape(-1, 4)
    bboxes = bboxes * torch.tensor([image.shape[2], image.shape[1], image.shape[2], image.shape[1]], dtype=torch.float32)
    drawn = draw_bounding_boxes(image,bboxes,width=15,colors="red")
    save_image(drawn, training_dir.parent / "drawn_bboxes" / f"{image_path.stem}.jpg")
# Out:
# 684it [01:24,  8.12it/s]

# %%
to_tensor = transforms.ToTensor()
for image_path in tqdm(training_dir.rglob("*.jpg")):
    image = to_tensor(Image.open(image_path).convert("RGB"))
    boxes = [annotation for annotation in annotations if annotation["uuid"] == image_path.stem][0]["bounding_boxes"]
    bboxes = []
    for i, box in enumerate(boxes):
        if not box["face"]:
            continue
        bboxes.append([box["xmin"], box["ymin"], box["xmax"], box["ymax"]])
    bboxes = torch.tensor(bboxes, dtype=torch.float32).reshape(-1, 4)
    bboxes = bboxes * torch.tensor([image.shape[2], image.shape[1], image.shape[2], image.shape[1]], dtype=torch.float32)
    drawn = torchvision.utils.draw_bounding_boxes(image,bboxes,width=15,colors="red")
    torchvision.utils.save_image(drawn, training_dir.parent / "drawn_bboxes_no_faces" / f"{image_path.stem}.jpg")

# %%
for image in annotations:
    output_path = (Path("/Users/iman/ml-datasets/detection_boxes/mla_files") / image["uuid"]).with_suffix(".mla")
    # with open(output_path,"w") as f:
    #     json.dump(image,f)
# Out:
# {'filename': 'IMG_2989.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/eb10488eda67d74a7bc74946fb64b2f9.jpg', 'uuid': 'c04e55b6-d524-4df8-967a-2e16f4259b65', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.2161, 'xmax': 0.427, 'ymin': 0.8658, 'ymax': 0.9594, 'face': 8, 'orientation': 8}, {'class': 'Object', 'xmin': 0.2064, 'xmax': 0.433, 'ymin': 0.7596, 'ymax': 0.8637, 'face': 8, 'orientation': 8}, {'class': 'Object', 'xmin': 0.1899, 'xmax': 0.345, 'ymin': 0.0852, 'ymax': 0.1667, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8213, 'xmax': 0.979, 'ymin': 0.102, 'ymax': 0.1832, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6826, 'xmax': 0.974, 'ymin': 0.5827, 'ymax': 0.7076, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8546, 'xmax': 0.993, 'ymin': 0.2841, 'ymax': 0.3653, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1761, 'xmax': 0.378, 'ymin': 0.1969, 'ymax': 0.349, 'face': 7, 'orientation': 6}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_2990.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/eab17386c71cdb92ad6cc118232aadd9.jpg', 'uuid': '65d1521a-3dee-47b0-bce2-1b8c55e6a134', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.4755, 'xmax': 0.615, 'ymin': 0.2109, 'ymax': 0.3539, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4854, 'xmax': 0.597, 'ymin': 0.8333, 'ymax': 0.8695, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2411, 'xmax': 0.378, 'ymin': 0.2887, 'ymax': 0.3598, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4975, 'xmax': 0.668, 'ymin': 0.5649, 'ymax': 0.6863, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4877, 'xmax': 0.594, 'ymin': 0.798, 'ymax': 0.8333, 'face': 1, 'orientation': 12}, {'class': 'Object', 'xmin': 0.4833, 'xmax': 0.603, 'ymin': 0.8703, 'ymax': 0.9195, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8753, 'xmax': 0.993, 'ymin': 0.6074, 'ymax': 0.6668, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5894, 'xmax': 0.791, 'ymin': 0.7455, 'ymax': 0.8259, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8064, 'xmax': 0.947, 'ymin': 0.2095, 'ymax': 0.3465, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6318, 'xmax': 0.765, 'ymin': 0.2098, 'ymax': 0.3535, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0873, 'xmax': 0.24, 'ymin': 0.2898, 'ymax': 0.3612, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2317, 'xmax': 0.378, 'ymin': 0.2184, 'ymax': 0.2874, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0183, 'xmax': 0.182, 'ymin': 0.1132, 'ymax': 0.1865, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.177, 'xmax': 0.333, 'ymin': 0.11, 'ymax': 0.1831, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2918, 'xmax': 0.444, 'ymin': 0.7751, 'ymax': 0.8259, 'face': 1, 'orientation': 12}, {'class': 'Object', 'xmin': 0.0249, 'xmax': 0.309, 'ymin': 0.578, 'ymax': 0.6987, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0183, 'xmax': 0.157, 'ymin': 0.8474, 'ymax': 0.8874, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5074, 'xmax': 0.685, 'ymin': 0.4376, 'ymax': 0.5689, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2853, 'xmax': 0.447, 'ymin': 0.8276, 'ymax': 0.9236, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7432, 'xmax': 0.888, 'ymin': 0.0273, 'ymax': 0.1773, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6672, 'xmax': 0.879, 'ymin': 0.5608, 'ymax': 0.6764, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.3827, 'xmax': 0.476, 'ymin': 0.2841, 'ymax': 0.3571, 'face': 2, 'orientation': 14}, {'class': 'Object', 'xmin': 0.602, 'xmax': 0.743, 'ymin': 0.0271, 'ymax': 0.1776, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0161, 'xmax': 0.151, 'ymin': 0.8867, 'ymax': 0.9392, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_2987.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/9fffa1a2d8012e65f941cb99c39074c6.jpg', 'uuid': 'b4d87c5c-8a9d-4e58-ac2a-d879a7fd1b04', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.2339, 'xmax': 0.395, 'ymin': 0.4442, 'ymax': 0.5189, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2196, 'xmax': 0.423, 'ymin': 0.5517, 'ymax': 0.6946, 'face': 7, 'orientation': 6}, {'class': 'Object', 'xmin': 0.1748, 'xmax': 0.484, 'ymin': 0.1628, 'ymax': 0.3071, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.4396, 'xmax': 0.535, 'ymin': 0.0394, 'ymax': 0.1494, 'face': 3, 'orientation': 5}, {'class': 'Object', 'xmin': 0.8772, 'xmax': 0.999, 'ymin': 0.4433, 'ymax': 0.5148, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4002, 'xmax': 0.539, 'ymin': 0.4417, 'ymax': 0.5181, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_2988.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/f388acb4fcbcecc4a0cf53d341cc3e94.jpg', 'uuid': '7bf0e4b7-73d9-4ec7-8587-98eb065247e8', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.863, 'xmax': 1.0, 'ymin': 0.2898, 'ymax': 0.445, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0
 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0754, 'xmax': 0.224, 'ymin': 0.6624, 'ymax': 0.7875, 'face': 2, 'orientation': 2}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3003.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/65a7d899ee8dac86ff6f453f07988f23.jpg', 'uuid': '693d5197-2de9-4550-9a30-a998a840ce96', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.1919, 'xmax': 0.347, 'ymin': 0.2174, 'ymax': 0.3703, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6449, 'xmax': 0.792, 'ymin': 0.5993, 'ymax': 0.743, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3396, 'xmax': 0.488, 'ymin': 0.6004, 'ymax': 0.743, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6102, 'xmax': 0.773, 'ymin': 0.4172, 'ymax': 0.5672, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.7908, 'xmax': 0.945, 'ymin': 0.8636, 'ymax': 0.9314, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.687, 'xmax': 0.85, 'ymin': 0.188, 'ymax': 0.3603, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.522, 'xmax': 0.681, 'ymin': 0.2072, 'ymax': 0.3635, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.391, 'xmax': 0.48, 'ymin': 0.0968, 'ymax': 0.1998, 'face': 3, 'orientation': 17}, {'class': 'Object', 'xmin': 0.1465, 'xmax': 0.294, 'ymin': 0.4247, 'ymax': 0.5742, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4534, 'xmax': 0.614, 'ymin': 0.4204, 'ymax': 0.5723, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.2966, 'xmax': 0.441, 'ymin': 0.4245, 'ymax': 0.5724, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1384, 'xmax': 0.29, 'ymin': 0.7898, 'ymax': 0.9303, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0, 'xmax': 0.115, 'ymin': 0.6092, 'ymax': 0.7217, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7047, 'xmax': 0.873, 'ymin': 0.0864, 'ymax': 0.1696, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.1496, 'xmax': 0.243, 'ymin': 0.0025, 'ymax': 0.1034, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.0676, 'xmax': 0.163, 'ymin': 0.1076, 'ymax': 0.2085, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.0577, 'xmax': 0.154, 'ymin': 0.0057, 'ymax': 0.1067, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.1617, 'xmax': 0.25, 'ymin': 0.1067, 'ymax': 0.2052, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.1828, 'xmax': 0.338, 'ymin': 0.6015, 'ymax': 0.7472, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3444, 'xmax': 0.501, 'ymin': 0.2072, 'ymax': 0.3647, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7985, 'xmax': 0.997, 'ymin': 0.5977, 'ymax': 0.7438, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.259, 'xmax': 0.386, 'ymin': 0.1343, 'ymax': 0.206, 'face': 3, 'orientation': 16}, {'class': 'Object', 'xmin': 0.255, 'xmax': 0.385, 'ymin': 0.0697, 'ymax': 0.1394, 'face': 3, 'orientation': 4}, {'class': 'Object', 'xmin': 0.7754, 'xmax': 0.931, 'ymin': 0.4141, 'ymax': 0.564, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7921, 'xmax': 0.943, 'ymin': 0.7867, 'ymax': 0.8647, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6394, 'xmax': 0.787, 'ymin': 0.7898, 'ymax': 0.9334, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4867, 'xmax': 0.638, 'ymin': 0.5973, 'ymax': 0.742, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3005.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/a942d0c9d3cc63dc1f24b2e0300a58a3.jpg', 'uuid': '395dba05-42bd-4ff8-af48-1879f38246ec', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.3227, 'xmax': 0.492, 'ymin': 0.017, 'ymax': 0.2, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2042, 'xmax': 0.376, 'ymin': 0.2422, 'ymax': 0.4059, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6875, 'xmax': 0.871, 'ymin': 0.0135, 'ymax': 0.1967, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.505, 'xmax': 0.687, 'ymin': 0.0144, 'ymax': 0.1977, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.5326, 'xmax': 0.678, 'ymin': 0.8179, 'ymax': 0.9428, 'face': 3, 'orientation': 5}, {'class': 'Object', 'xmin': 0.5381, 'xmax': 0.702, 'ymin': 0.2341, 'ymax': 0.4007, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6935, 'xmax': 0.855, 'ymin': 0.4508, 'ymax': 0.6031, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7061, 'xmax': 0.877, 'ymin': 0.231, 'ymax': 0.3955, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6838, 'xmax': 0.827, 'ymin': 0.8169, 'ymax': 0.9428, 'face': 3, 'orientation': 5}, {'class': 'Object', 'xmin': 0.0121, 'xmax': 0.183, 'ymin': 0.461, 'ymax': 0.6057, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.466, 'xmax': 0.613, 'ymin': 0.6431, 'ymax': 0.7846, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3867, 'xmax': 0.529, 'ymin': 0.8192, 'ymax': 0.9395, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6135, 'xmax': 0.828, 'ymin': 0.6529, 'ymax': 0.7929, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1495, 'xmax': 0.326, 'ymin': 0.0271, 'ymax': 0.205, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8338, 'xmax': 0.985, 'ymin': 0.82, 'ymax': 0.9449, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1683, 'xmax': 0.328, 'ymin': 0.4579, 'ymax': 0.6036, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2474, 'xmax': 0.388, 'ymin': 0.8169, 'ymax': 0.9316, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3756, 'xmax': 0.535, 'ymin': 0.2414, 'ymax': 0.4038, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8214, 'xmax': 0.99, 'ymin': 0.6562, 'ymax': 0.7914, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3356, 'xmax': 0.471, 'ymin': 0.6363, 'ymax': 0.7718, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.0008, 'xmax': 0.138, 'ymin': 0.2562, 'ymax': 0.4039, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3004.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/ab49e13206234962198065ec7df22ac4.jpg', 'uuid': '94dfd033-f5c2-4a21-bccd-f51811338021', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.3811, 'xmax': 0.493, 'ymin': 0.3036, 'ymax': 0.4634, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.7703, 'xmax': 0.951, 'ymin': 0.3144, 'ymax': 0.4757, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3535, 'xmax': 0.6, 'ymin': 0.0952, 'ymax': 0.2693, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3756, 'xmax': 0.542, 'ymin': 0.5138, 'ymax': 0.669, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.7643, 'xmax': 0.927, 'ymin': 0.1144, 'ymax': 0.2769, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0008, 'xmax': 0.171, 'ymin': 0.0632, 'ymax': 0.1593, 'face': 9, 'orientation': 10}, {'class': 'Object', 'xmin': 0.0, 'xmax': 0.173, 'ymin': 0.1553, 'ymax': 0.2495, 'face': 9, 'orientation': 10}, {'class': 'Object', 'xmin': 0.274, 'xmax': 0.551, 'ymin': 0.7413, 'ymax': 0.871, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.8144, 'xmax': 0.95, 'ymin': 0.7128, 'ymax': 0.8626, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.6964, 'xmax': 0.863, 'ymin': 0.5265, 'ymax': 0.6786, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0919, 'xmax': 0.257, 'ymin': 0.7167, 'ymax': 0.8644, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.538, 'xmax': 0.704, 'ymin': 0.5179, 'ymax': 0.6746, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.1871, 'xmax': 0.357, 'ymin': 0.0847, 'ymax': 0.2615, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0889, 'xmax': 0.376, 'ymin': 0.5325, 'ymax': 0.6664, 'face': 8, 'orientation': 8}, {'class': 'Object', 'xmin': 0.4936, 'xmax': 0.642, 'ymin': 0.3154, 'ymax': 0.4671, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3006.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/1be9f108c2ebb945afa3671a1399e67a.jpg', 'uuid': '6a8fb05c-6bf5-4d46-9098-9caf3efd4e85', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.37, 'xmax': 0.61, 'ymin': 0.1792, 'ymax': 0.3015, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.8268, 'xmax': 0.939, 'ymin': 0.1862, 'ymax': 0.3143, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.1328, 'xmax': 0.267, 'ymin': 0.4811, 'ymax': 0.6033, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.869, 'xmax': 0.998, 'ymin': 0.3372, 'ymax': 0.4696, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2009, 'xmax': 0.334, 'ymin': 0.6453, 'ymax': 0.7699, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4282, 'xmax': 0.552, 'ymin': 0.6397, 'ymax': 0.7556, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8171, 'xmax': 0.967, 'ymin': 0.6721, 'ymax': 0.7597, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5176, 'xmax': 0.645, 'ymin': 0.4885, 'ymax': 0.6073, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5552, 'xmax': 0.678, 'ymin': 0.6388, 'ymax': 0.7579, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6752, 'xmax': 0.801, 'ymin': 0.6377, 'ymax': 0.7524, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3339, 'xmax': 0.468, 'ymin': 0.3244, 'ymax': 0.4585, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.643, 'xmax': 0.777, 'ymin': 0.4882, 'ymax': 0.6076, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.4683, 'xmax': 0.599, 'ymin': 0.3279, 'ymax': 0.4625, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2684, 'xmax': 0.393, 'ymin': 0.4814, 'ymax': 0.6044, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1896, 'xmax': 0.334, 'ymin': 0.3196, 'ymax': 0.4547, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.7272, 'xmax': 0.87, 'ymin': 0.3362, 'ymax': 0.4639, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3952, 'xmax': 0.522, 'ymin': 0.4837, 'ymax': 0.6008, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2063, 'xmax': 0.352, 'ymin': 0.1498, 'ymax': 0.2955, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0343, 'xmax': 0.183, 'ymin': 0.1415, 'ymax': 0.2873, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8459, 'xmax': 0.972, 'ymin': 0.4935, 'ymax': 0.6044, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5961, 'xmax': 0.71, 'ymin': 0.3415, 'ymax': 0.4589, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0509, 'xmax': 0.191, 'ymin': 0.6555, 'ymax': 0.7701, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7694, 'xmax': 0.855, 'ymin': 0.49, 'ymax': 0.6056, 'face': 2, 'orientation': 2}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_2996.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/d6bb4a807708a20b8e945e4b560abe0d.jpg', 'uuid': 'bbbb9485-2a87-4328-be26-84aba6f19787', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.6354, 'xmax': 0.806, 'ymin': 0.4253, 'ymax': 0.5862, 'face': 9, 'orientation': 11}, {'class': 'Object', 'xmin': 0.1354, 'xmax': 0.396, 'ymin': 0.6429, 'ymax': 0.7783, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.7733, 'xmax': 0.924, 'ymin': 0.2414, 'ymax': 0.3924, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1726, 'xmax': 0.405, 'ymin': 0.867, 'ymax': 0.9634, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2787, 'xmax': 0.435, 'ymin': 0.2397, 'ymax': 0.3941, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8444, 'xmax': 0.997, 'ymin': 0.0517, 'ymax': 0.2053, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0205, 'xmax': 0.186, 'ymin': 0.0419, 'ymax': 0.2003, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4975, 'xmax': 0.655, 'ymin': 0.0493, 'ymax': 0.2011, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6835, 'xmax': 0.841, 'ymin': 0.0493, 'ymax': 0.2036, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1868, 'xmax': 0.351, 'ymin': 0.0443, 'ymax': 0.2003, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.701, 'xmax': 0.952, 'ymin': 0.6585, 'ymax': 0.7709, 'face': 8, 'orientation': 8}, {'class': 'Object', 'xmin': 0.8378, 'xmax': 0.99, 'ymin': 0.4647, 'ymax': 0.5813, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0697, 'xmax': 0.231, 'ymin': 0.2348, 'ymax': 0.3924, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6245, 'xmax': 0.772, 'ymin': 0.3161, 'ymax': 0.3933, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3958, 'xmax': 0.539, 'ymin': 0.7053, 'ymax': 0.775, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_2994.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/485ed8937697ec152e27d1f4bd68b56d.jpg', 'uuid': 'e062a216-9e9d-4bc6-b748-b6b4cf330af7', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.6289, 'xmax': 0.751, 'ymin': 0.0197, 'ymax': 0.1511, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0
 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5139, 'xmax': 0.649, 'ymin': 0.2258, 'ymax': 0.298, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3002.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/10eb9ae75b3bb54b115efca23996e5f9.jpg', 'uuid': '0b9825a8-dca8-416a-b6ca-8950e05edc02', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.7686, 'xmax': 0.945, 'ymin': 0.564, 'ymax': 0.7193, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4822, 'xmax': 0.627, 'ymin': 0.5649, 'ymax': 0.6856, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3294, 'xmax': 0.571, 'ymin': 0.3616, 'ymax': 0.5312, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1637, 'xmax': 0.408, 'ymin': 0.1195, 'ymax': 0.294, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3716, 'xmax': 0.534, 'ymin': 0.7617, 'ymax': 0.9108, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.5381, 'xmax': 0.691, 'ymin': 0.7586, 'ymax': 0.9126, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.75, 'xmax': 0.921, 'ymin': 0.3629, 'ymax': 0.5293, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6933, 'xmax': 0.86, 'ymin': 0.7671, 'ymax': 0.9139, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0149, 'xmax': 0.158, 'ymin': 0.1061, 'ymax': 0.2976, 'face': 3, 'orientation': 17}, {'class': 'Object', 'xmin': 0.0818, 'xmax': 0.362, 'ymin': 0.7988, 'ymax': 0.9199, 'face': 8, 'orientation': 8}, {'class': 'Object', 'xmin': 0.4105, 'xmax': 0.659, 'ymin': 0.1228, 'ymax': 0.2987, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1514, 'xmax': 0.323, 'ymin': 0.3609, 'ymax': 0.5299, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8368, 'xmax': 0.999, 'ymin': 0.1174, 'ymax': 0.2989, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8236, 'xmax': 0.97, 'ymin': 0.032, 'ymax': 0.1133, 'face': 3, 'orientation': 16}, {'class': 'Object', 'xmin': 0.595, 'xmax': 0.692, 'ymin': 0.3528, 'ymax': 0.5037, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.3688, 'xmax': 0.474, 'ymin': 0.5609, 'ymax': 0.7139, 'face': 2, 'orientation': 2}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3014.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/d8b95752807f19bd48116b043a8f9eb8.jpg', 'uuid': '4e08139e-6744-445b-9d9a-f8a76eb690d6', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.7184, 'xmax': 0.873, 'ymin': 0.4144, 'ymax': 0.5634, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.887, 'xmax': 0.999, 'ymin': 0.5172, 'ymax': 0.6716, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.0274, 'xmax': 0.202, 'ymin': 0.0083, 'ymax': 0.1779, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5666, 'xmax': 0.712, 'ymin': 0.4188, 'ymax': 0.5641, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4131, 'xmax': 0.565, 'ymin': 0.4214, 'ymax': 0.5672, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0509, 'xmax': 0.226, 'ymin': 0.2383, 'ymax': 0.3923, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.2175, 'xmax': 0.385, 'ymin': 0.2331, 'ymax': 0.3913, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.1961, 'xmax': 0.366, 'ymin': 0.0, 'ymax': 0.172, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0
 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8062, 'xmax': 0.999, 'ymin': 0.2931, 'ymax': 0.4811, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7935, 'xmax': 0.981, 'ymin': 0.7499, 'ymax': 0.9057, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.4739, 'xmax': 0.633, 'ymin': 0.7495, 'ymax': 0.9037, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.839, 'xmax': 0.999, 'ymin': 0.5452, 'ymax': 0.7159, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1109, 'xmax': 0.361, 'ymin': 0.2849, 'ymax': 0.4704, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1027, 'xmax': 0.293, 'ymin': 0.531, 'ymax': 0.6105, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6355, 'xmax': 0.806, 'ymin': 0.7473, 'ymax': 0.903, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.1065, 'xmax': 0.29, 'ymin': 0.6131, 'ymax': 0.696, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3010.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/175062bbfff1976568d827e9432dcdb0.jpg', 'uuid': '9d73b808-3253-4a0d-8ca3-ac8f41f55a23', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.0885, 'xmax': 0.322, 'ymin': 0.6045, 'ymax': 0.7679, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7819, 'xmax': 0.953, 'ymin': 0.1714, 'ymax': 0.3355, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4505, 'xmax': 0.548, 'ymin': 0.0449, 'ymax': 0.1574, 'face': 3, 'orientation': 17}, {'class': 'Object', 'xmin': 0.6084, 'xmax': 0.786, 'ymin': 0.1638, 'ymax': 0.2476, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8626, 'xmax': 0.988, 'ymin': 0.4144, 'ymax': 0.5984, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3397, 'xmax': 0.496, 'ymin': 0.8076, 'ymax': 0.9555, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5492, 'xmax': 0.649, 'ymin': 0.0391, 'ymax': 0.1521, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.5068, 'xmax': 0.664, 'ymin': 0.8142, 'ymax': 0.9607, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.5196, 'xmax': 0.687, 'ymin': 0.4005, 'ymax': 0.5605, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1129, 'xmax': 0.294, 'ymin': 0.4013, 'ymax': 0.5681, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.6752, 'xmax': 0.841, 'ymin': 0.6016, 'ymax': 0.7529, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6751, 'xmax': 0.833, 'ymin': 0.8066, 'ymax': 0.9567, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3482, 'xmax': 0.449, 'ymin': 0.0427, 'ymax': 0.1582, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.0008, 'xmax': 0.175, 'ymin': 0.1616, 'ymax': 0.3401, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1689, 'xmax': 0.252, 'ymin': 0.1424, 'ymax': 0.202, 'face': 3, 'orientation': 4}, {'class': 'Object', 'xmin': 0.4405, 'xmax': 0.523, 'ymin': 0.2142, 'ymax': 0.3398, 'face': 3, 'orientation': 5}, {'class': 'Object', 'xmin': 0.6913, 'xmax': 0.855, 'ymin': 0.3995, 'ymax': 0.5626, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2989, 'xmax': 0.518, 'ymin': 0.4016, 'ymax': 0.5616, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4974, 'xmax': 0.66, 'ymin': 0.5976, 'ymax': 0.7545, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1911, 'xmax': 0.349, 'ymin': 0.0063, 'ymax': 0.1603, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.0, 'xmax': 0.151, 'ymin': 0.8163, 'ymax': 0.9715, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6069, 'xmax': 0.779, 'ymin': 0.2513, 'ymax': 0.3379, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3549, 'xmax': 0.439, 'ymin': 0.21, 'ymax': 0.3165, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1823, 'xmax': 0.269, 'ymin': 0.2089, 'ymax': 0.3359, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1631, 'xmax': 0.325, 'ymin': 0.8241, 'ymax': 0.9769, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.2761, 'xmax': 0.36, 'ymin': 0.211, 'ymax': 0.3176, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5257, 'xmax': 0.606, 'ymin': 0.2183, 'ymax': 0.3432, 'face': 3, 'orientation': 5}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3012.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/f578e41c42d0bd516c0b48ab4719aad6.jpg', 'uuid': 'c7d032cd-03cd-4527-8827-c2729757b4f1', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.1518, 'xmax': 0.315, 'ymin': 0.7352, 'ymax': 0.892, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.0014, 'xmax': 0.151, 'ymin': 0.7444, 'ymax': 0.8947, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.2275, 'xmax': 0.487, 'ymin': 0.0261, 'ymax': 0.2343, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6788, 'xmax': 0.858, 'ymin': 0.5114, 'ymax': 0.6829, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3239, 'xmax': 0.487, 'ymin': 0.7376, 'ymax': 0.8944, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0235, 'xmax': 0.229, 'ymin': 0.0402, 'ymax': 0.2402, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.6834, 'xmax': 0.89, 'ymin': 0.0036, 'ymax': 0.213, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.486, 'xmax': 0.68, 'ymin': 0.0143, 'ymax': 0.2248, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4916, 'xmax': 0.667, 'ymin': 0.515, 'ymax': 0.6835, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.4756, 'xmax': 0.654, 'ymin': 0.2705, 'ymax': 0.4546, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.308, 'xmax': 0.494, 'ymin': 0.52, 'ymax': 0.6849, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6717, 'xmax': 0.872, 'ymin': 0.2526, 'ymax': 0.4521, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0155, 'xmax': 0.276, 'ymin': 0.2746, 'ymax': 0.4686, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4959, 'xmax': 0.659, 'ymin': 0.7352, 'ymax': 0.892, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1072, 'xmax': 0.288, 'ymin': 0.5311, 'ymax': 0.699, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# {'filename': 'IMG_3013.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/b548744567b47159887b39027e42fb77.jpg', 'uuid': '61238c4f-a546-4b6f-8cf9-e91675f53276', 'width': 3024, 'height': 4032, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.6655, 'xmax': 0.822, 'ymin': 0.4465, 'ymax': 0.5917, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8339, 'xmax': 0.997, 'ymin': 0.015, 'ymax': 0.1941, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0345, 'xmax': 0.181, 'ymin': 0.6118, 'ymax': 0.7468, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4865, 'xmax': 0.628, 'ymin': 0.7887, 'ymax': 0.9141, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4923, 'xmax': 0.642, 'ymin': 0.2574, 'ymax': 0.4105, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.7195, 'xmax': 0.917, 'ymin': 0.6244, 'ymax': 0.7585, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6437, 'xmax': 0.807, 'ymin': 0.2592, 'ymax': 0.4128, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.8223, 'xmax': 0.975, 'ymin': 0.4497, 'ymax': 0.5953, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3386, 'xmax': 0.48, 'ymin': 0.7948, 'ymax': 0.9139, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1812, 'xmax': 0.322, 'ymin': 0.6177, 'ymax': 0.7503, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6572, 'xmax': 0.823, 'ymin': 0.0244, 'ymax': 0.1977, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3248, 'xmax': 0.483, 'ymin': 0.2559, 'ymax': 0.4086, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1387, 'xmax': 0.298, 'ymin': 0.2556, 'ymax': 0.4131, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0172, 'xmax': 0.175, 'ymin': 0.4367, 'ymax': 0.587, 'face': 1, 'orientation': 1}, {'class': 'Object', 'xmin': 0.4883, 'xmax': 0.654, 'ymin': 0.0291, 'ymax': 0.1977, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0014, 'xmax': 0.153, 'ymin': 0.0331, 'ymax': 0.1976, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3161, 'xmax': 0.481, 'ymin': 0.0322, 'ymax': 0.1141, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0472, 'xmax': 0.183, 'ymin': 0.7799, 'ymax': 0.9112, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3161, 'xmax': 0.483, 'ymin': 0.1162, 'ymax': 0.1981, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3244, 'xmax': 0.464, 'ymin': 0.615, 'ymax': 0.7492, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3234, 'xmax': 0.474, 'ymin': 0.4435, 'ymax': 0.5903, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.1533, 'xmax': 0.312, 'ymin': 0.0312, 'ymax': 0.1138, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.6829, 'xmax': 0.877, 'ymin': 0.7986, 'ymax': 0.9293, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4667, 'xmax': 0.715, 'ymin': 0.6416, 'ymax': 0.7503, 'face': 8, 'orientation': 8}, {'class': 'Object', 'xmin': 0.1533, 'xmax': 0.312, 'ymin': 0.114, 'ymax': 0.1967, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.175, 'xmax': 0.324, 'ymin': 0.4424, 'ymax': 0.5891, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.4811, 'xmax': 0.628, 'ymin': 0.4458, 'ymax': 0.5896, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.8056, 'xmax': 0.975, 'ymin': 0.2578, 'ymax': 0.4125, 'face': 2, 'orientation': 2}, {'class': 'Object', 'xmin': 0.1967, 'xmax': 0.332, 'ymin': 0.7839, 'ymax': 0.9116, 'face': 1, 'orientation': 0}], 'store': 'bf71326f-5168-48d9-9cd3-f7f5c32cd94c'}
# ...
# {'filename': 'c95f7a29-7162-4f87-af66-eb91916fa9b4.jpg', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/51aa7009bfd2967cfb22f02197ac5904.jpg', 'uuid': '7a0940c7-2ca1-4b91-8fbe-320753bf36ed', 'width': 1536, 'height': 2049, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.1445, 'xmax': 0.386, 'ymin': 0.8032, 'ymax': 0.9246, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0
 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.5584, 'xmax': 0.763, 'ymin': 0.4781, 'ymax': 0.564, 'face': 7, 'orientation': 7}, {'class': 'Object', 'xmin': 0.5557, 'xmax': 0.761, 'ymin': 0.3868, 'ymax': 0.48, 'face': 7, 'orientation': 7}, {'class': 'Object', 'xmin': 0.4534, 'xmax': 0.675, 'ymin': 0.0717, 'ymax': 0.1297, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3336, 'xmax': 0.468, 'ymin': 0.1593, 'ymax': 0.207, 'face': 3, 'orientation': 4}, {'class': 'Object', 'xmin': 0.9107, 'xmax': 0.984, 'ymin': 0.7679, 'ymax': 0.796, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.7023, 'xmax': 0.822, 'ymin': 0.2804, 'ymax': 0.3405, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.3333, 'xmax': 0.539, 'ymin': 0.3864, 'ymax': 0.4817, 'face': 3, 'orientation': 16}, {'class': 'Object', 'xmin': 0.6757, 'xmax': 0.883, 'ymin': 0.0081, 'ymax': 0.0787, 'face': 1, 'orientation': 13}, {'class': 'Object', 'xmin': 0.8352, 'xmax': 1.0, 'ymin': 0.2123, 'ymax': 0.2574, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.845, 'xmax': 0.997, 'ymin': 0.2574, 'ymax': 0.3391, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.001, 'xmax': 0.171, 'ymin': 0.4357, 'ymax': 0.5037, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.001, 'xmax': 0.175, 'ymin': 0.5064, 'ymax': 0.568, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.8413, 'xmax': 0.998, 'ymin': 0.1664, 'ymax': 0.2114, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.5946, 'xmax': 0.646, 'ymin': 0.3443, 'ymax': 0.3613, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.5835, 'xmax': 0.704, 'ymin': 0.2299, 'ymax': 0.3415, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0858, 'xmax': 0.16, 'ymin': 0.9094, ...
# {'filename': 'IMG_0027.JPG', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/4674e0d1817e62be7e24425de59a6686.jpg', 'uuid': 'bbe3cac3-d99b-42e6-b04e-90e4722aa536', 'width': 1114, 'height': 1300, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.2091, 'xmax': 0.807, 'ymin': 0.2541, 'ymax': 0.6318, 'face': None, 'orientation': None}], 'store': '7a31d692-8a0d-42b3-96f4-c81613ed0477'}
# {'filename': '640d57f1-451c-4577-b225-cffe84900d2a.jpg', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/861e0eb25a39a9fad155a61d69f1cfc2.jpg', 'uuid': '697a7719-dac8-4950-b6e3-dd174245575c', 'width': 1536, 'height': 2049, 'bounding_boxes': [{'class': 'Object', 'xmin': 0.0098, 'xmax': 0.403, 'ymin': 0.0, 'ymax': 0.1281, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.6987, 'xmax': 0.859, 'ymin': 0.9079, 'ymax': 0.9778, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.7058, 'xmax': 0.839, 'ymin': 0.1426, 'ymax': 0.2041, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.1772, 'xmax': 0.319, 'ymin': 0.907, 'ymax': 0.9756, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.2298, 'xmax': 0.363, 'ymin': 0.1355, 'ymax': 0.2002, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.2751, 'xmax': 0.677, 'ymin': 0.6579, 'ymax': 0.8904, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.0734, 'xmax': 0.231, 'ymin': 0.1307, 'ymax': 0.1984, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.2807, 'xmax': 0.688, 'ymin': 0.4144, 'ymax': 0.6557, 'face': 1, 'orientation': 0}, {'class': 'Object', 'xmin': 0.002, 'xmax': 0.251, 'ymin': 0.4109, 'ymax': 0.6524, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.0, 'xmax': 0.242, 'ymin': 0.6568, 'ymax': 0.8895, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.7544, 'xmax': 0.99, 'ymin': 0.4476, 'ymax': 0.5966, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.833, 'xmax': 0.937, 'ymin': 0.0, 'ymax': 0.0589, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.444, 'xmax': 0.825, 'ymin': 0.0, 'ymax': 0.1325, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.8291, 'xmax': 0.937, 'ymin': 0.0633, 'ymax': 0.1384, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.7582, 'xmax': 0.996, 'ymin': 0.6009, 'ymax': 0.7496, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.5417, 'xmax': 0.7, 'ymin': 0.1376, 'ymax': 0.2043, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.7661, 'xmax': 0.992, 'ymin': 0.7526, 'ymax': 0.8895, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.3286, 'xmax': 0.493, 'ymin': 0.9066, 'ymax': 0.9767, 'face': None, 'orientation': None}, {'class': 'Object', 'xmin': 0.874, 'xmax': 0.999, 'ymin': 0.1426, 'ymax': 0.2057, 'face': None, 'orientation': None}], 'store': '7a31d692-8a0d-42b3-96f4-c81613ed0477'}

# %%
## re download images for validated/cleaned MLAs
for folder in Path("/Users/iman/Downloads/vq-mla_files-download/MLA files").iterdir():
    urls = []
    uuids = []
    output_path = Path("/Users/iman/ml-datasets/detection_boxes/mla_files/" + folder.name + "_checked")
    output_path.mkdir(parents=True, exist_ok=True)
    for file in folder.rglob("*.mla"):
        with open(file) as f:
            data = json.load(f)
        urls.append(data["url"])
        uuids.append(data["uuid"])
    asyncio.run(download_images(urls, uuids, output_path))
# Out:
# Collected images' bytes!
# Collected images' bytes!
# Collected images' bytes!

# %%
all_images_paths = []
for image_path in Path("/Users/iman/ml-datasets/detection_boxes/all_checked").rglob("*.jpg"):
    all_images_paths.append(image_path.stem)

# %%
training_uuids = [mla_path.stem for mla_path in Path("/Users/iman/ml-datasets/detection_boxes/mla_files/all_checked_filtered").rglob("*.mla")]

# %%
f"https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&filter={quote(uuids_filter)}"
# Out:
# 'https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&filter=uuid%3D4abae850-77c7-46eb-b8d9-4cfc3d5ed34d%2Cuuid%3Dba0ce192-4004-4f6d-88ea-445c9f5228f9%2Cuuid%3D41a94560-89e2-4c71-8586-95a09100e6e4%2Cuuid%3D8ccedb7d-17c3-4d20-929e-879a53bf5797%2Cuuid%3Df630fb54-e7d9-4156-be03-ee3f6c572cf6%2Cuuid%3Db810bd29-8b90-437c-968c-eaa727a0f1be%2Cuuid%3D2302d787-5b63-4d47-beb3-2555a7743f93%2Cuuid%3D62672095-fb34-40e8-bf3d-1ea7be814285%2Cuuid%3D2e56d25a-351c-47c6-8456-f7ab5b59e1a8%2Cuuid%3Db3c18d4f-7fd2-4828-b3ca-4469a4e24ea5%2Cuuid%3Df80544dd-8d94-4165-b18a-d33417eb892b%2Cuuid%3D9d0f6c62-917d-4f43-90ce-d15891ef3dc7%2Cuuid%3Da41671f7-5311-4fbe-92fa-a
uid%3D5d2bcf88-1a54-448f-b227-94b95ce2551f%2Cuuid%3Df59930db-9f40-45c0-b824-a0f8bc632101%2Cuuid%3Dc0921521-683c-497d-b675-96bd74500e40%2Cuuid%3Dc975aec9-1df4-44c1-9cf6-127735f81810%2Cuuid%3D1a67cd7d-e940-4d7d-987b-2049e1eefb26%2Cuuid%3D85d10f76-fc7b-435b-b447-8e2fb7cbd947%2Cuuid%3Dc38e0e2d-a0b7-491a-a49f-e7c9d480896a%2Cuuid%3D4f911560-0deb-4574-bb68-6c68d37e860b%2Cuuid%3Da15bf93e-7507-48fc-804f-fd33d2443e45%2Cuuid%3D822de444-86a1-480a-85f4-ed1bc40eeced%2Cuuid%3D8cf7c9bc-8636-4fab-92e0-74b7bd4409ce%2Cuuid%3D6b394ac1-9acd-4756-8697-8ec67f333ce1%2Cuuid%3D3ee212b6-161d-4585-ab64-4532037feb7a%2Cuuid%3D7b2144f0-31cc-4022-8c0e-61ac4965860d%2Cuuid%3Dfac1b958-8910-4e6a-9ad9-3ed4dd44d029%2Cuuid%3Dec8a0369-99f4-4519-96e3-63c9953e9a98%2Cuuid%3D7ee641fd-6839-4fcf-9e55-22fc4e0ae3a6%2Cuuid%3D6afc7d9d-ca5c-45cc-9622-8ad01aa8d151%2Cuuid%3D7bf961ed-f41b-4a70-81c5-67f98bc7164e%2Cuuid%3De981df9e-e306-42a0-b49a-58939108938a%2Cuuid%3Ddaf8efbf-e411-4a4f-a93f-95b4cc314db2%2Cuuid%3D7a456580-e06b-44de-b0c7-f1b94631a355%2Cuuid%3Df0722f17-87cd-4a86-8b3b-eb346da1fd01%2Cuuid%3D42526bd0-ea4c-41c3-949e-94067c41c1c1%2Cuuid%3Df53cf932-8e28-421a-9ac9-67dc94428c3a%2Cuuid%3D6a0b66f1-bfca-4fde-86a5-89f6f21dd352%2Cuuid%3D0794249d-770e-436a-92ab-76368b8c9edb%2Cuuid%3D58a1a2b2-86f5-47a5-bfa3-a64e6a13f34c%2Cuuid%3D90980120-4d55-4ab5-9a64-064722681df8%2Cuuid%3D2033c82b-6f5a-4d83-8eb8-2b31e5200ce2%2Cuui ...

# %%
# if using annotations directly from VQ
# don't use if you've cleaned annotations 

login_url = "https://api.345.global/api/v1/login/access-token"
credentials = {"username": username, "password": password,"grant_type": "password"}
response = requests.post(login_url, data=credentials)
token_response = response.json()

from PIL import Image
#access_token = token_response["access_token"]
token_type = token_response.get("token_type", "Bearer") 
token = token_response.get("access_token", None)

# 2. Set headers
headers = {
    "Authorization": f"{token_type} {token}"
}

uuids_filter = ""
for uuid in training_uuids:
    uuids_filter += f"uuid={uuid},"
uuids_filter = uuids_filter[:-1]  # Remove the last comma

from urllib.parse import quote
annotations = []
images_api = set()
url = f"https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&filter={quote(uuids_filter)}"
response = requests.get(url, headers=headers)
response_data = response.json()
print(response_data)
all_images = response_data["data"]
print(len(all_images))

for image in all_images:

    filename = image["filename"]
    uuid = image["uuid"]
    # # Skip stitched images and duplicates
    # if "stitched_image" in filename:
    #     continue

    entry = {
        "filename": filename,
        "url": image["url"],
        "uuid": uuid,
        "width": None,
        "height": None,
        "bounding_boxes": [],
        "store": store
    }
    uuid_path = uuid + ".jpg"
    image_path = Path("/Users/iman/ml-datasets/detection_boxes/all_checked_filtered") / uuid_path
    if image_path.exists():
        w, h = Image.open(image_path).size
        entry["width"] = w
        entry["height"] = h

        for annotation in image.get("annotations", []):
            anno = {
                "class": "Object",
                "xmin": annotation["xmin"],
                "xmax": annotation["xmax"],
                "ymin": annotation["ymin"],
                "ymax": annotation["ymax"],
                "face": annotation["face"],
                "orientation": annotation["orientation"]
            }
            entry["bounding_boxes"].append(anno)

        annotations.append(entry)
# Out:
# {'total_count': 130, 'page_count': 130, 'query_count': 130, 'data': [{'uuid': '77a2782a-b91c-4440-958c-a874ff573391', 'fileHash': '01fd46632eedf62ffb2edc35a7bb61d9f60802b3806dbeb2488c69bec854d42c', 'fileHashMd5': 'c1447b2a8941d88a473f99a451f96f3e', 'filename': 'IMG_3429.JPG', 'extension': 'jpg', 'folder': 'ml_store_images', 'size': 1897880, 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/c1447b2a8941d88a473f99a451f96f3e.jpg', 'scope': None, 'lat': 44.87403055555556, 'lng': -93.324325, 'upcLocations': None, 'surveyJobUuid': None, 'createdAt': '2020-10-28T01:59:43.911300+00:00', 'updatedAt': '2020-10-28T02:44:56.697302+00:00', 'updateIndex': -1290, 'deletedAt': None, 'createdBy': None, 'store': {'uuid': '160334d6-a310-4429-b460-c26e19de203e', 'name': 'Mark 1', 'retailerName': None, 'address': None, 'city': None, 'state': None, 'zipCode': None}, 'annotations': [{'uuid': 'caa8a5e7-cbb2-42bd-b62b-b0af96625cd7', 'xmin': 0.7238, 'xmax': 0.822, 'ymin': 0.0467, 'ymax': 0.1214, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '5c8b92cd-2fda-4c24-a4ba-d43f7977f22c', 'xmin': 0.603, 'xmax': 0.7, 'ymin': 0.4204, 'ymax': 0.4983, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '427a5123-efc5-4e02-bf42-0e96747c4e45', 'xmin': 0.8076, 'xmax': 0.912, 'ymin': 0.2874, 'ymax': 0.3614, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '3c2a6c9f-869d-4def-91f5-3df48a9feab6', 'xmin': 0.8073, 'xmax': 0.909, 'ymin': 0.4219, 'ymax': 0.4932, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'a2ad9d57-3f64-42e8-964b-cff5ccd524d8', 'xmin': 0.2833, 'xmax': 0.392, 'ymin': 0.0433, 'ymax': 0.1225, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '493249d6-928f-4e16-9cb6-853db818dfe0', 'xmin': 0.6034, 'xmax': 0.697, 'ymin': 0.6536, 'ymax': 0.7038, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '31b5f47e-edf1-4602-bdc8-3d1530c31404', 'xmin': 0.4955, 'xmax': 0.615, 'ymin': 0.7438, 'ymax': 0.8375, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'dd451921-640d-4317-8ed8-048274b593bb', 'xmin': 0.6988, 'xmax': 0.797, 'ymin': 0.4213, 'ymax': 0.4973, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '9926af21-acb6-455b-8d10-996ebd429a43', 'xmin': 0.3063, 'xmax': 0.402, 'ymin': 0.6486, 'ymax': 0.7043, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '15ba7344-a95f-4c57-945f-b611fb067dcf', 'xmin': 0.7585, 'xmax': 0.888, 'ymin': 0.5227, 'ymax': 0.6182, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'f486122a-f5cc-4e1e-be6c-36e92c98f172', 'xmin': 0.2836, 'xmax': 0.383, 'ymin': 0.169, 'ymax': 0.2494, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '7a971126-120a-469a-91c8-d3576aa66944', 'xmin': 0.8114, 'xmax': 0.914, 'ymin': 0.1706, 'ymax': 0.2469, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '25c6c737-e46f-4690-8c3d-0db6c9a94fca', 'xmin': 0.5067, 'xmax': 0.615, 'ymin': 0.0422, 'ymax': 0.1214, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'd64c9aca-eab4-4db0-891c-8d492b8490f9', 'xmin': 0.1872, 'xmax': 0.281, 'ymin': 0.1698, 'ymax': 0.2486, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '9f6ce1af-737d-45fa-bbde-ebb5d4819b9d', 'xmin': 0.7061, 'xmax': 0.808, 'ymin': 0.2856, 'ymax': 0.3638, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'c5bada16-f8d9-4d41-9fd8-2e757821103e', 'xmin': 0.2901, 'xmax': 0.39, 'ymin': 0.286, 'ymax': 0.3665, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '95e915d3-8efa- ...
# 130

# %%
from urllib.parse import quote

login_url = "https://api.345.global/api/v1/login/access-token"
credentials = {"username": username, "password": password,"grant_type": "password"}
response = requests.post(login_url, data=credentials)
token_response = response.json()

from PIL import Image
#access_token = token_response["access_token"]
token_type = token_response.get("token_type", "Bearer") 
token = token_response.get("access_token", None)
# 2. Set headers
headers = {
    "Authorization": f"{token_type} {token}"
}

url = f"https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&filter={quote(f"uuid=4abae850-77c7-46eb-b8d9-4cfc3d5ed34d")}"
response = requests.get(url, headers=headers)
response_data = response.json()
print(response_data)
all_images = response_data["data"]
# Out:
# {'total_count': 1, 'page_count': 1, 'query_count': 1, 'data': [{'uuid': '4abae850-77c7-46eb-b8d9-4cfc3d5ed34d', 'fileHash': '7b7bd0c6e1dc9f726a37d63a5ca1de0aa7b57aae4958911e0700683373c1e9f1', 'fileHashMd5': '28b1ff4bf20fde6dab18d654ca7b38ea', 'filename': 'IMG_0080.JPG', 'extension': 'jpg', 'folder': 'ml_store_images', 'size': 510686, 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/28b1ff4bf20fde6dab18d654ca7b38ea.jpg', 'scope': None, 'lat': 35.93865833333333, 'lng': -86.81939722222222, 'upcLocations': None, 'surveyJobUuid': None, 'createdAt': '2020-10-28T02:00:37.496189+00:00', 'updatedAt': '2020-10-28T18:52:26.388165+00:00', 'updateIndex': -1339, 'deletedAt': None, 'createdBy': None, 'store': {'uuid': '1830657b-f07a-4fee-8879-274113a9d7b7', 'name': 'Kendall 1', 'retailerName': None, 'address': None, 'city': None, 'state': None, 'zipCode': None}, 'annotations': [{'uuid': 'a5b0f093-ec9a-463e-afce-b20fdb17c976', 'xmin': 0.4772, 'xmax': 0.651, 'ymin': 0.5218, 'ymax': 0.7894, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '2cf47d22-a799-438f-93a3-3d61773334fe', 'xmin': 0.6514, 'xmax': 0.769, 'ymin': 0.1356, 'ymax': 0.3716, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '68da38aa-f614-4a7d-91fc-5f2c91594ad0', 'xmin': 0.2749, 'xmax': 0.477, 'ymin': 0.5096, 'ymax': 0.7871, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '5c877425-c1d4-4469-9590-177f2337112f', 'xmin': 0.0472, 'xmax': 0.261, 'ymin': 0.5142, 'ymax': 0.795, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '231931fa-eb51-422d-940d-4ab4e9f6e94c', 'xmin': 0.0139, 'xmax': 0.156, 'ymin': 0.1314, 'ymax': 0.3715, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'c9549629-b733-46e7-a18f-967241519241', 'xmin': 0.1609, 'xmax': 0.289, 'ymin': 0.1352, 'ymax': 0.372, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '505120e8-ecc2-40ea-a358-8303cc75e816', 'xmin': 0.7673, 'xmax': 0.892, 'ymin': 0.1388, 'ymax': 0.3747, 'annotationType': None, 'productUuid': 'bbc4cb6d-a2f4-426b-860f-03eb5cd9a96b', 'face': 1, 'orientation': 0}, {'uuid': 'd3b81cb8-2959-4959-986e-732edb64d40e', 'xmin': 0.2883, 'xmax': 0.416, 'ymin': 0.1297, 'ymax': 0.3718, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '2358065e-be8f-41fc-8475-144ff97a28b6', 'xmin': 0.5337, 'xmax': 0.649, 'ymin': 0.1328, 'ymax': 0.3746, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '3a6bfcf1-93e9-4dea-9d45-60d45ee9a0de', 'xmin': 0.6491, 'xmax': 0.83, 'ymin': 0.5132, 'ymax': 0.7819, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '9835e572-bc82-4c2a-a435-a2bb46ee1a6f', 'xmin': 0.416, 'xmax': 0.537, 'ymin': 0.1386, 'ymax': 0.3697, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}], 'numberOfAnnotations': 11, 'numberOfAnnotationsWithProducts': 1}]}
# [{'uuid': '4abae850-77c7-46eb-b8d9-4cfc3d5ed34d',
#   'fileHash': '7b7bd0c6e1dc9f726a37d63a5ca1de0aa7b57aae4958911e0700683373c1e9f1',
#   'fileHashMd5': '28b1ff4bf20fde6dab18d654ca7b38ea',
#   'filename': 'IMG_0080.JPG',
#   'extension': 'jpg',
#   'folder': 'ml_store_images',
#   'size': 510686,
#   'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/28b1ff4bf20fde6dab18d654ca7b38ea.jpg',
#   'scope': None,
#   'lat': 35.93865833333333,
#   'lng': -86.81939722222222,
#   'upcLocations': None,
#   'surveyJobUuid': None,
#   'createdAt': '2020-10-28T02:00:37.496189+00:00',
#   'updatedAt': '2020-10-28T18:52:26.388165+00:00',
#   'updateIndex': -1339,
#   'deletedAt': None,
#   'createdBy': None,
#   'store': {'uuid': '1830657b-f07a-4fee-8879-274113a9d7b7',
#    'name': 'Kendall 1',
#    'retailerName': None,
#    'address': None,
#    'city': None,
#    'state': None,
#    'zipCode': None},
#   'annotations': [{'uuid': 'a5b0f093-ec9a-463e-afce-b20fdb17c976',
#     'xmin': 0.4772,
#     'xmax': 0.651,
#     'ymin': 0.5218,
#     'ymax': 0.7894,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '2cf47d22-a799-438f-93a3-3d61773334fe',
#     'xmin': 0.6514,
#     'xmax': 0.769,
#     'ymin': 0.1356,
#     'ymax': 0.3716,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '68da38aa-f614-4a7d-91fc-5f2c91594ad0',
#     'xmin': 0.2749,
#     'xmax': 0.477,
#     'ymin': 0.5096,
#     'ymax': 0.7871,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '5c877425-c1d4-4469-9590-177f2337112f',
#     'xmin': 0.0472,
#     'xmax': 0.261,
#     'ymin': 0.5142,
#     'ymax': 0.795,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '231931fa-eb51-422d-940d-4ab4e9f6e94c',
#     'xmin': 0.0139,
#     'xmax': 0.156,
#     'ymin': 0.1314,
#     'ymax': 0.3715,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': 'c9549629-b733-46e7-a18f-967241519241',
#     'xmin': 0.1609,
#     'xmax': 0.289,
#     'ymin': 0.1352,
#     'ymax': 0.372,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '505120e8-ecc2-40ea-a358-8303cc75e816',
#     'xmin': 0.7673,
#     'xmax': 0.892,
#     'ymin': 0.1388,
#     'ymax': 0.3747,
#     'annotationType': None,
#     'productUuid': 'bbc4cb6d-a2f4-426b-860f-03eb5cd9a96b',
#     'face': 1,
#     'orientation': 0},
#    {'uuid': 'd3b81cb8-2959-4959-986e-732edb64d40e',
#     'xmin': 0.2883,
#     'xmax': 0.416,
#     'ymin': 0.1297,
#     'ymax': 0.3718,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '2358065e-be8f-41fc-8475-144ff97a28b6',
#     'xmin': 0.5337,
#     'xmax': 0.649,
#     'ymin': 0.1328,
#     'ymax': 0.3746,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '3a6bfcf1-93e9-4dea-9d45-60d45ee9a0de',
#     'xmin': 0.6491,
#     'xmax': 0.83,
#     'ymin': 0.5132,
#     'ymax': 0.7819,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None},
#    {'uuid': '9835e572-bc82-4c2a-a435-a2bb46ee1a6f',
#     'xmin': 0.416,
#     'xmax': 0.537,
#     'ymin': 0.1386,
#     'ymax': 0.3697,
#     'annotationType': None,
#     'productUuid': None,
#     'face': None,
#     'orientation': None}],
#   'numberOfAnnotations': 11,
#   'numberOfAnnotationsWithProducts': 1}]

# %%
all_images[0]
# Out:
# {'uuid': '4abae850-77c7-46eb-b8d9-4cfc3d5ed34d',
#  'fileHash': '7b7bd0c6e1dc9f726a37d63a5ca1de0aa7b57aae4958911e0700683373c1e9f1',
#  'fileHashMd5': '28b1ff4bf20fde6dab18d654ca7b38ea',
#  'filename': 'IMG_0080.JPG',
#  'extension': 'jpg',
#  'folder': 'ml_store_images',
#  'size': 510686,
#  'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/28b1ff4bf20fde6dab18d654ca7b38ea.jpg',
#  'scope': None,
#  'lat': 35.93865833333333,
#  'lng': -86.81939722222222,
#  'upcLocations': None,
#  'surveyJobUuid': None,
#  'createdAt': '2020-10-28T02:00:37.496189+00:00',
#  'updatedAt': '2020-10-28T18:52:26.388165+00:00',
#  'updateIndex': -1339,
#  'deletedAt': None,
#  'createdBy': None,
#  'store': {'uuid': '1830657b-f07a-4fee-8879-274113a9d7b7',
#   'name': 'Kendall 1',
#   'retailerName': None,
#   'address': None,
#   'city': None,
#   'state': None,
#   'zipCode': None},
#  'annotations': [{'uuid': 'a5b0f093-ec9a-463e-afce-b20fdb17c976',
#    'xmin': 0.4772,
#    'xmax': 0.651,
#    'ymin': 0.5218,
#    'ymax': 0.7894,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '2cf47d22-a799-438f-93a3-3d61773334fe',
#    'xmin': 0.6514,
#    'xmax': 0.769,
#    'ymin': 0.1356,
#    'ymax': 0.3716,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '68da38aa-f614-4a7d-91fc-5f2c91594ad0',
#    'xmin': 0.2749,
#    'xmax': 0.477,
#    'ymin': 0.5096,
#    'ymax': 0.7871,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '5c877425-c1d4-4469-9590-177f2337112f',
#    'xmin': 0.0472,
#    'xmax': 0.261,
#    'ymin': 0.5142,
#    'ymax': 0.795,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '231931fa-eb51-422d-940d-4ab4e9f6e94c',
#    'xmin': 0.0139,
#    'xmax': 0.156,
#    'ymin': 0.1314,
#    'ymax': 0.3715,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': 'c9549629-b733-46e7-a18f-967241519241',
#    'xmin': 0.1609,
#    'xmax': 0.289,
#    'ymin': 0.1352,
#    'ymax': 0.372,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '505120e8-ecc2-40ea-a358-8303cc75e816',
#    'xmin': 0.7673,
#    'xmax': 0.892,
#    'ymin': 0.1388,
#    'ymax': 0.3747,
#    'annotationType': None,
#    'productUuid': 'bbc4cb6d-a2f4-426b-860f-03eb5cd9a96b',
#    'face': 1,
#    'orientation': 0},
#   {'uuid': 'd3b81cb8-2959-4959-986e-732edb64d40e',
#    'xmin': 0.2883,
#    'xmax': 0.416,
#    'ymin': 0.1297,
#    'ymax': 0.3718,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '2358065e-be8f-41fc-8475-144ff97a28b6',
#    'xmin': 0.5337,
#    'xmax': 0.649,
#    'ymin': 0.1328,
#    'ymax': 0.3746,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '3a6bfcf1-93e9-4dea-9d45-60d45ee9a0de',
#    'xmin': 0.6491,
#    'xmax': 0.83,
#    'ymin': 0.5132,
#    'ymax': 0.7819,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None},
#   {'uuid': '9835e572-bc82-4c2a-a435-a2bb46ee1a6f',
#    'xmin': 0.416,
#    'xmax': 0.537,
#    'ymin': 0.1386,
#    'ymax': 0.3697,
#    'annotationType': None,
#    'productUuid': None,
#    'face': None,
#    'orientation': None}],
#  'numberOfAnnotations': 11,
#  'numberOfAnnotationsWithProducts': 1}

# %%
# if using annotations from local cleaned 
annotations = []

for mla_path in Path("/Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered").rglob("*.mla"):
    with open(mla_path) as f:
        image = json.load(f)
        print(mla_path,image)
        uuid = image["uuid"]
        # # Skip stitched images and duplicates
        # if "stitched_image" in filename:
        #     continue
        filename = image.get("filename")
        store = image.get("store")
        if not filename or not store:
            url = f"https://api.345.global/api/v1/productMLStoreImages/paginate?skip=0&limit=10000&filter={quote(f"uuid={uuid}")}"
            response = requests.get(url, headers=headers)
            response_data = response.json()
            image_data = response_data["data"]
            filename = image_data[0]["filename"]
            store = image_data[0]["store"]
        
        entry = {
            "filename": filename,
            "url": image["url"],
            "uuid": uuid,
            "width": None,
            "height": None,
            "bounding_boxes": [],
            "store": store
        }
        uuid_path = uuid + ".jpg"
        image_path = Path("/Users/iman/ml-datasets/detection_boxes/misc/all_checked_filtered") / uuid_path
        if image_path.exists():
            w, h = Image.open(image_path).size
            entry["width"] = w
            entry["height"] = h

            for annotation in image.get("annotations", []):
                anno = {
                    "class": "Object",
                    "xmin": annotation["xmin"],
                    "xmax": annotation["xmax"],
                    "ymin": annotation["ymin"],
                    "ymax": annotation["ymax"],
                    "face": annotation.get("face",0),
                    "orientation": annotation.get("orientation",0)
                }
                entry["bounding_boxes"].append(anno)

            annotations.append(entry)
# Out:
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/4abae850-77c7-46eb-b8d9-4cfc3d5ed34d.mla {'version': 2, 'uuid': '4abae850-77c7-46eb-b8d9-4cfc3d5ed34d', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/28b1ff4bf20fde6dab18d654ca7b38ea.jpg', 'mlInfo': None, 'annotations': [{'uuid': '68da38aa-f614-4a7d-91fc-5f2c91594ad0', 'xmin': 0.2749, 'ymin': 0.5096, 'xmax': 0.477, 'ymax': 0.7871, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '231931fa-eb51-422d-940d-4ab4e9f6e94c', 'xmin': 0.0139, 'ymin': 0.1314, 'xmax': 0.156, 'ymax': 0.3715, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'c9549629-b733-46e7-a18f-967241519241', 'xmin': 0.1609, 'ymin': 0.1352, 'xmax': 0.289, 'ymax': 0.372, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '505120e8-ecc2-40ea-a358-8303cc75e816', 'xmin': 0.7673, 'ymin': 0.1388, 'xmax': 0.892, 'ymax': 0.3747, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'd3b81cb8-2959-4959-986e-732edb64d40e', 'xmin': 0.2883, 'ymin': 0.1297, 'xmax': 0.416, 'ymax': 0.3718, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '2358065e-be8f-41fc-8475-144ff97a28b6', 'xmin': 0.5337, 'ymin': 0.1328, 'xmax': 0.649, 'ymax': 0.3746, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '3a6bfcf1-93e9-4dea-9d45-60d45ee9a0de', 'xmin': 0.6491, 'ymin': 0.5132, 'xmax': 0.83, 'ymax': 0.7819, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '9835e572-bc82-4c2a-a435-a2bb46ee1a6f', 'xmin': 0.416, 'ymin': 0.1386, 'xmax': 0.537, 'ymax': 0.3697, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'a5b0f093-ec9a-463e-afce-b20fdb17c976', 'xmin': 0.4772, 'ymin': 0.5218, 'xmax': 0.651, 'ymax': 0.7894, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '2cf47d22-a799-438f-93a3-3d61773334fe', 'xmin': 0.6514, 'ymin': 0.1356, 'xmax': 0.769, 'ymax': 0.3716, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '5c877425-c1d4-4469-9590-177f2337112f', 'xmin': 0.0472, 'ymin': 0.5142, 'xmax': 0.261, 'ymax': 0.795, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '2394a735-d71c-4f1c-9087-f4b3f38998aa', 'xmin': 0.8485053566209539, 'ymin': 0.5222542586821266, 'xmax': 0.999937441988398, 'ymax': 0.7855665052213627, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}]}
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/ba0ce192-4004-4f6d-88ea-445c9f5228f9.mla {'uuid': 'ba0ce192-4004-4f6d-88ea-445c9f5228f9', 'fileHash': '5a5e23aa0355e24d8b382497020d01745856a12be566d72a6c01ee746a2d3288', 'fileHashMd5': '63baaeab40b9c9c98ef99938a9d72691', 'filename': 'IMG_0022.JPG', 'extension': 'jpg', 'folder': 'ml_store_images', 'size': 588026, 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/63baaeab40b9c9c98ef99938a9d72691.jpg', 'scope': None, 'lat': 35.93879444444444, 'lng': -86.81935833333333, 'upcLocations': None, 'surveyJobUuid': None, 'createdAt': '2020-10-28T02:01:12.001282+00:00', 'updatedAt': '2020-11-09T16:10:55.580177+00:00', 'updateIndex': -1374, 'deletedAt': None, 'createdBy': None, 'store': {'uuid': '1830657b-f07a-4fee-8879-274113a9d7b7', 'name': 'Kendall 1', 'retailerName': None, 'address': None, 'city': None, 'state': None, 'zipCode': None}, 'annotations': [{'uuid': '0123de72-e956-4d7a-a265-77138d2dc7d7', 'xmin': 0.795, 'xmax': 0.998, 'ymin': 0.6928, 'ymax': 0.9093, 'annotationType': None, 'productUuid': 'f496797b-8a49-4227-ba8a-88c2e7b6dabe', 'face': 1, 'orientation': 0}, {'uuid': '8dfa5af0-f971-4606-920b-bb78898e1e58', 'xmin': 0.5416, 'xmax': 0.808, 'ymin': 0.0625, 'ymax': 0.3424, 'annotationType': None, 'productUuid': 'aa6012ae-ed87-487e-a0b5-237e4f848ad0', 'face': 1, 'orientation': 0}, {'uuid': '70f11a6f-08a3-4cc3-9ec1-e4c19d4e6195', 'xmin': 0.0, 'xmax': 0.229, 'ymin': 0.0687, 'ymax': 0.2113, 'annotationType': None, 'productUuid': '0cd64483-56ec-4421-9ba4-b8e9adf16f48', 'face': 1, 'orientation': 0}, {'uuid': 'ee702929-c78f-4584-bf99-9481bc247ba0', 'xmin': 0.2426, 'xmax': 0.51, 'ymin': 0.213, 'ymax': 0.346, 'annotationType': None, 'productUuid': '0cd64483-56ec-4421-9ba4-b8e9adf16f48', 'face': 1, 'orientation': 0}, {'uuid': '7f43d0d1-91e1-42ff-9da8-1fd40a39d21a', 'xmin': 0.0007, 'xmax': 0.241, 'ymin': 0.2112, 'ymax': 0.3442, 'annotationType': None, 'productUuid': '0cd64483-56ec-4421-9ba4-b8e9adf16f48', 'face': 1, 'orientation': 0}, {'uuid': '8f573a66-9043-4f73-8d55-95ecbcaa451d', 'xmin': 0.2308, 'xmax': 0.494, 'ymin': 0.0687, 'ymax': 0.2095, 'annotationType': None, 'productUuid': '0cd64483-56ec-4421-9ba4-b8e9adf16f48', 'face': 1, 'orientation': 0}, {'uuid': '27d6cdba-f4e4-4d04-b85b-3b3342f74258', 'xmin': 0.0631, 'xmax': 0.395, 'ymin': 0.3969, 'ymax': 0.6465, 'annotationType': None, 'productUuid': '611b54e0-158d-4434-9d2c-4e5c77006bb3', 'face': 1, 'orientation': 0}, {'uuid': '491fccb8-0b6d-4389-8473-670b714928d7', 'xmin': 0.4054, 'xmax': 0.744, 'ymin': 0.3927, 'ymax': 0.6416, 'annotationType': None, 'productUuid': '611b54e0-158d-4434-9d2c-4e5c77006bb3', 'face': 1, 'orientation': 0}, {'uuid': '20cb75c8-3d73-4d27-bd84-7662b8634fbc', 'xmin': 0.3527, 'xmax': 0.55, 'ymin': 0.6954, 'ymax': 0.8275, 'annotationType': None, 'productUuid': '886daad8-c979-4270-90b3-38c8c3e029d3', 'face': 1, 'orientation': 0}, {'uuid': 'edf1c72d-9fa1-44a0-b47e-6b4ae79812cf', 'xmin': 0.7481, 'xmax': 0.998, 'ymin': 0.3939, 'ymax': 0.6343, 'annotationType': None, 'productUuid': 'cf51d28b-f534-404d-a4a7-d7d911335be0', 'face': 1, 'orientation': 0}, {'uuid': '9cafa027-425f-4929-b962-4a3d49bd1a63', 'xmin': 0.0828, 'xmax': 0.319, 'ymin': 0.7011, 'ymax': 0.9012, 'annotationType': None, 'productUuid': 'f0905c16-d0d3-47ee-9813-7feda196a6c9', 'face': 1, 'orientation': 0}, {'uuid': '2b14780c-9984-4326-a5b5-70b158f9715a', 'xmin': 0.5521, 'xmax': 0.782, 'ymin': 0.692, 'ymax': 0.8913, 'annotationType': None, 'productUuid': 'f496797b-8a49-4227-ba8a-88c2e7b6dabe', 'face': 1, 'orientation': 0}], 'numberOfAnnotations': 12, 'numberOfAnnotationsWithProducts': 12}
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/41a94560-89e2-4c71-8586-95a09100e6e4.mla {'version': 2, 'uuid': '41a94560-89e2-4c71-8586-95a09100e6e4', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/54a8193b4395b433d4d773fc29eac1c4.jpg', 'mlInfo': None, 'annotations': [{'uuid': '4054b79a-d307-48a0-9912-9baac6076ce0', 'xmin': 0.6216, 'ymin': 0.6348, 'xmax': 0.833, 'ymax': 0.9008, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '392c1d0f-e02a-408b-ba62-dfe83a2d1f2c', 'xmin': 0.4239, 'ymin': 0.0422, 'xmax': 0.623, 'ymax': 0.2811, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '3f8b8600-e6d6-46bf-8983-b8088282a7ac', 'xmin': 0.0224, 'ymin': 0.0617, 'xmax': 0.215, 'ymax': 0.2896, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '47d71e0a-105c-4b89-8762-1f2b3413fe0f', 'xmin': 0.0146, 'ymin': 0.6406, 'xmax': 0.218, 'ymax': 0.9008, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '21fbc2d8-5cc7-483f-8b82-dc72af0683e6', 'xmin': 0.6263, 'ymin': 0.0633, 'xmax': 0.818, 'ymax': 0.2786, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 
493b190e5432bc8.jpg', 'scope': None, 'lat': 35.938827777777774, 'lng': -86.81948055555556, 'upcLocations': None, 'surveyJobUuid': None, 'createdAt': '2020-10-28T02:01:23.399041+00:00', 'updatedAt': '2020-11-09T16:00:33.164258+00:00', 'updateIndex': -1386, 'deletedAt': None, 'createdBy': None, 'store': {'uuid': '1830657b-f07a-4fee-8879-274113a9d7b7', 'name': 'Kendall 1', 'retailerName': None, 'address': None, 'city': None, 'state': None, 'zipCode': None}, 'annotations': [{'uuid': '97fca3ee-0940-439e-8702-24d7e7ed7b97', 'xmin': 0.0217, 'xmax': 0.311, 'ymin': 0.2378, 'ymax': 0.3571, 'annotationType': None, 'productUuid': '0ad63655-362b-4517-a1e0-72a6453ba847', 'face': 9, 'orientation': 10}, {'uuid': '539f09a0-076d-4f60-a3f0-ecd2ff370847', 'xmin': 0.2578, 'xmax': 0.415, 'ymin': 0.8564, 'ymax': 0.9421, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'caca8db9-5d20-4efd-8276-7971074f2868', 'xmin': 0.6448, 'xmax': 0.952, 'ymin': 0.2113, 'ymax': 0.3623, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '784f6485-41d6-452a-8d7a-d01efb305fe3', 'xmin': 0.0746, 'xmax': 0.241, 'ymin': 0.8574, 'ymax': 0.9437, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '88d3f839-81ea-4670-8b05-2d40abacc4fd', 'xmin': 0.8277, 'xmax': 0.964, 'ymin': 0.852, 'ymax': 0.9323, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '19eec598-023d-4547-8729-c31809e36ac1', 'xmin': 0.6307, 'xmax': 0.781, 'ymin': 0.7738, 'ymax': 0.8609, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'c84a793a-a930-4661-a0fd-15d4d1294b25', 'xmin': 0.6026, 'xmax': 0.76, 'ymin': 0.5203, 'ymax': 0.6355, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'aa88e239-e29e-451c-8f6b-a635a22acceb', 'xmin': 0.6002, 'xmax': 0.757, 'ymin': 0.4085, 'ymax': 0.5185, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'e16a2638-f38b-4e09-91de-2be427c68f2f', 'xmin': 0.3408, 'xmax': 0.639, 'ymin': 0.2115, 'ymax': 0.3633, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '5b8c4a8a-d782-4841-93f4-c9e8853ccce1', 'xmin': 0.4418, 'xmax': 0.605, 'ymin': 0.7746, 'ymax': 0.8618, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'cfca0b28-9144-4d8d-a3d7-0a1bd804eee0', 'xmin': 0.6494, 'xmax': 0.943, 'ymin': 0.0687, 'ymax': 0.2092, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '414da09f-a2cd-4a3b-a318-ad1610fce650', 'xmin': 0.6293, 'xmax': 0.782, 'ymin': 0.8636, 'ymax': 0.9461, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '86161e70-a86c-4acb-9f7b-d894f612813c', 'xmin': 0.2588, 'xmax': 0.551, 'ymin': 0.4818, 'ymax': 0.6369, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '10b1cd8e-45bb-489d-af36-23c139b3332b', 'xmin': 0.8009, 'xmax': 0.969, 'ymin': 0.7527, 'ymax': 0.8415, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': '7d4fbb8e-8894-43e2-a492-4a0f73c5a915', 'xmin': 0.2577, 'xmax': 0.408, 'ymin': 0.7699, 'ymax': 0.8599, 'annotationType': None, 'productUuid': None, 'face': None, 'orientation': None}, {'uuid': 'b7823dc8-16e5-4fea-85e1-b2db03bd3a76', 'xmin': 0.7645, 'xmax': 0.922, 'ymin': 0.5212, 'ymax': 0.6364, 'annotationTy ...
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/2e56d25a-351c-47c6-8456-f7ab5b59e1a8.mla {'version': 2, 'uuid': '2e56d25a-351c-47c6-8456-f7ab5b59e1a8', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/728b548efc49e70267ce9f6d87332007.jpg', 'mlInfo': None, 'annotations': [{'uuid': '89e0e1de-ae70-4bb9-a0ed-513ffb2ac0ae', 'xmin': 0.8941, 'ymin': 0.6618, 'xmax': 1, 'ymax': 0.779, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'c1d84a3c-631c-484d-889c-cad3b7945beb', 'xmin': 0.7586, 'ymin': 0.6618, 'xmax': 0.884, 'ymax': 0.779, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'a65d2e50-3c86-4047-b6b9-9d2c88758470', 'xmin': 0.3531, 'ymin': 0.3442, 'xmax': 0.487, 'ymax': 0.4751, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '440f2e8d-ab9b-4d92-8490-d9dc2b8f969e', 'xmin': 0.7624, 'ymin': 0.5008, 'xmax': 0.888, 'ymax': 0.6258, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'a8386979-2d2a-49a7-954c-f843dd97e1bc', 'xmin': 0.629, 'ymin': 0.5012, 'xmax': 0.757, 'ymax': 0.6256, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '6f296ab3-aa9a-47de-82eb-eef8d9719b1d', 'xmin': 0.7705, 'ymin': 0.3369, 'xmax': 0.907, 'ymax': 0.4711, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '698b6bc3-4af4-4728-99d3-ed67fa630a71', 'xmin': 0.0142, 'ymin': 0, 'xmax': 0.164, 'ymax': 0.1325, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '44531f68-4284-4110-9717-e2398cdee960', 'xmin': 0.3021, 'ymin': 0.1887, 'xmax': 0.426, 'ymax': 0.3176, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '9b2ea0ae-8fe6-4669-b3b9-801481e12689', 'xmin': 0.4269, 'ymin': 0.1805, 'xmax': 0.561, 'ymax': 0.3163, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '6362d13b-b070-4847-b78d-cc833bbdb1d0', 'xmin': 0.6285, 'ymin': 0.3349, 'xmax': 0.761, 'ymax': 0.4749, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 
 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '5f37b1ce-f3fc-4d49-91ee-a238a08fc3b5', 'xmin': 0.8538187631250749, 'ymin': 0.5142750996960891, 'xmax': 0.9946240354842772, 'ymax': 0.7037801256144789, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '011bf3a0-80a4-4f05-ad5b-b04837c1a8ea', 'xmin': 0.8591321696291957, 'ymin': 0.7077697051074976, 'xmax': 0.999937441988398, 'ymax': 0.8813164130538123, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'bbc53f82-c2d4-437f-8bc6-444ef751cd87', 'xmin': 0.7369238200344163, 'ymin': 0.23899411467779672, 'xmax': 0.9972807387363376, 'ymax': 0.44844703806128006, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}]}
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/f80544dd-8d94-4165-b18a-d33417eb892b.mla {'uuid': 'f80544dd-8d94-4165-b18a-d33417eb892b', 'fileHash': 'b8ca2174870fdc4af37eed3f070f9ed09c4666648c6dd6ffe1fb60a7259b008d', 'fileHashMd5': 'b7250a77413d79617478d583fe0bdfe7', 'filename': 'IMG_2966.JPG', 'extension': 'jpg', 'folder': 'ml_store_images', 'size': 1563732, 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/b7250a77413d79617478d583fe0bdfe7.jpg', 'scope': None, 'lat': 36.1957112, 'lng': -94.1837538, 'upcLocations': None, 'surveyJobUuid': None, 'createdAt': '2020-10-29T17:38:52.464648+00:00', 'updatedAt': '2020-11-23T11:56:38.801471+00:00', 'updateIndex': -1433, 'deletedAt': None, 'createdBy': None, 'store': {'uuid': '59d021de-d665-443d-9ce5-5ba6d6a7e1c0', 'name': '4870 Elm Springs Rd', 'retailerName': None, 'address': '4870 Elm Springs Rd', 'city': 'Springdale', 'state': 'AR', 'zipCode': '72762'}, 'annotations': [{'uuid': 'c4ad8706-e673-47aa-bbf6-3899ebf56254', 'xmin': 0.0, 'xmax': 0.14, 'ymin': 0.2016, 'ymax': 0.3637, 'annotationType': None, 'productUuid': 'd871ab97-eaf6-418e-8c49-6b3a5b86032e', 'face': 1, 'orientation': 0}, {'uuid': 'd983fc2f-6001-40d4-ac09-8bfbc5562d9b', 'xmin': 0.7618, 'xmax': 0.897, 'ymin': 0.2343, 'ymax': 0.377, 'annotationType': None, 'productUuid': '6e8d833f-79b4-4b76-bc82-fe8c80d7ce4e', 'face': 1, 'orientation': 0}, {'uuid': '31354634-9ef1-4c33-989e-912792dc95a1', 'xmin': 0.8783, 'xmax': 0.998, 'ymin': 0.782, 'ymax': 0.8345, 'annotationType': None, 'productUuid': '0215645c-8ae4-4594-83f8-e9fa16dabe2f', 'face': 9, 'orientation': 10}, {'uuid': 'ee555149-541b-4a5b-a482-6af26109c7f3', 'xmin': 0.8194, 'xmax': 0.982, 'ymin': 0.8334, 'ymax': 0.9254, 'annotationType': None, 'productUuid': '3181ae82-2d21-46b0-afb8-505d48792166', 'face': 1, 'orientation': 0}, {'uuid': '199fb7a2-d3cb-4044-8a78-4b7930e26dd2', 'xmin': 0.8767, 'xmax': 0.998, 'ymin': 0.7273, 'ymax': 0.7821, 'annotationType': None, 'productUuid': '0215645c-8ae4-4594-83f8-e9fa16dabe2f', 'face': 2, 'orientation': 3}, {'uuid': '5e9868fb-5d39-47ac-a287-f7d6a7e6a964', 'xmin': 0.0758, 'xmax': 0.301, 'ymin': 0.8613, 'ymax': 0.958, 'annotationType': None, 'productUuid': '34ae40ca-4cac-4832-88e4-dc1140d16514', 'face': 8, 'orientation': 8}, {'uuid': 'a9f23705-213f-4ea1-9406-0ff13a13cb81', 'xmin': 0.8342, 'xmax': 0.989, 'ymin': 0.0298, 'ymax': 0.1984, 'annotationType': None, 'productUuid': '44719d9c-b04b-4b08-b41c-1ccb2ee1d357', 'face': 1, 'orientation': 0}, {'uuid': '340a01f4-3606-4ada-adcd-266989715c4b', 'xmin': 0.8664, 'xmax': 0.998, 'ymin': 0.5686, 'ymax': 0.6901, 'annotationType': None, 'productUuid': '07d32518-7f86-4d40-bde8-2921391f9182', 'face': 1, 'orientation': 0}, {'uuid': '4b320d63-e180-4d2e-b6be-d14601925e2a', 'xmin': 0.4786, 'xmax': 0.586, 'ymin': 0.7949, 'ymax': 0.8508, 'annotationType': None, 'productUuid': '0215645c-8ae4-4594-83f8-e9fa16dabe2f', 'face': 9, 'orientation': 10}, {'uuid': 'f0302efd-a304-43cf-8132-dec886ed439f', 'xmin': 0.5113, 'xmax': 0.665, 'ymin': 0.0158, 'ymax': 0.1878, 'annotationType': None, 'productUuid': 'fd903ce4-5e00-4d4c-89d8-9ced2c6d77e1', 'face': 1, 'orientation': 0}, {'uuid': 'ef5d9702-4caf-4a6f-976e-d0fa57c69648', 'xmin': 0.6669, 'xmax': 0.827, 'ymin': 0.0239, 'ymax': 0.1913, 'annotationType': None, 'productUuid': '8e530cfb-7fd2-4c3c-bbbe-a1ac6143a5b1', 'face': 1, 'orientation': 0}, {'uuid': '42738dd9-dd7f-4d7d-a014-89cf5cd290fc', 'xmin': 0.6419, 'xmax': 0.85, 'ymin': 0.7739, 'ymax': 0.8613, 'annotationType': None, 'productUuid': '5b8eaeea-07ca-452e-9b9f-119f8d1a9be5', 'face': 8, 'orientation': 8}, {'uuid': 'f105f856-527a-4284-b7cd-9e960c9a4c28', 'xmin': 0.3084, 'xmax': 0.471, 'ymin': 0.8277, 'ymax': 0.9318, 'annotationType': None, 'productUuid': 'c24c7375-2010-460d-9d8d-66d21b013daa', 'face': 1, 'orientation': 0}, {'uuid': '779a3ec0-5d4d-4cab-806c-ed0b0985bf0f', 'xmin': 0.6217, 'xmax': 0.822, 'ymin': 0.8625, 'ymax': 0.9487, 'annotationType': None, 'productUuid': '5b8e ...
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/9d0f6c62-917d-4f43-90ce-d15891ef3dc7.mla {'version': 2, 'uuid': '9d0f6c62-917d-4f43-90ce-d15891ef3dc7', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/8db3aa54319a85ac3fb8a377e06caf83.jpg', 'mlInfo': None, 'annotations': [{'uuid': '2230f694-99d3-409f-b041-cbc6da424172', 'xmin': 0.4956, 'ymin': 0.4519, 'xmax': 0.601, 'ymax': 0.5526, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid':
 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'bd660495-6892-4d31-8595-a50d0d1ee83e', 'xmin': 0.6689, 'ymin': 0.18, 'xmax': 0.782, 'ymax': 0.2954, 'predictions': [], ' ...
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/a41671f7-5311-4fbe-92fa-a80ce15bb9c8.mla {'version': 2, 'uuid': 'a41671f7-5311-4fbe-92fa-a80ce15bb9c8', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/7d4c06d19e53c8a39044c48382512146.jpg', 'mlInfo': None, 'annotations': [{'uuid': 'e543bcbb-b36d-4660-86ee-90d61187e835', 'xmin': 0.1189, 'ymin': 0.359, 'xmax': 0.327, 'ymax': 0.606, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '453bd98c-5fc5-4bc8-bc0f-1a0504869d7c', 'xmin': 0.5687, 'ymin': 0.671, 'xmax': 0.839, 'ymax': 0.9323, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'ca1fae66-1eda-46be-8a10-e2396efe0801', 'xmin': 0.2091, 'ymin': 0.0667, 'xmax': 0.421, 'ymax': 0.2951, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '2bb48994-44a1-4f95-97c0-bf348a2abdf3', 'xmin': 0.1453, 'ymin': 0.6891, 'xmax': 0.354, 'ymax': 0.9328, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '56869425-a786-44b7-9770-c9138047dcc4', 'xmin': 0.3367, 'ymin': 0.3628, 'xmax': 0.548, 'ymax': 0.6057, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'daf6a145-23ab-4960-a376-fe9c00d0b1ab', 'xmin': 0.0021, 'ymin': 0.0642, 'xmax': 0.208, 'ymax': 0.2963, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '1686f073-aebb-42ee-8f12-f9af482742d2', 'xmin': 0.3492, 'ymin': 0.687, 'xmax': 0.569, 'ymax': 0.9314, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'bf40ce98-634a-461f-9ca8-8542d2b9204e', 'xmin': 0.5562, 'ymin': 0.3417, 'xmax': 0.821, 'ymax': 0.607, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '543f690e-e04e-4501-a89c-bb2096e801f9', 'xmin': 0.6714, 'ymin': 0.0554, 'xmax': 0.88, 'ymax': 0.2911, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '0db39f51-db84-488c-952d-b2903eb6e425', 'xmin': -0.004296387290441478, 'ymin': 0.3766546731259172, 'xmax': 0.10462844604403584, 'ymax': 0.6020292503238054, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '33ea8147-65a8-4f9c-8940-74cf6e5e05f1', 'xmin': 0.0010170192136793568, 'ymin': 0.7057414451405327, 'xmax': 0.1391655883208213, 'ymax': 0.9331104876233579, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '37cc1930-6126-47c1-9f3d-3edb82708385', 'xmin': 0.8458486533688935, 'ymin': 0.6558798130171061, 'xmax': 0.999937441988398, 'ymax': 0.9251326264836097, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'f4a2594c-44fd-4604-a37f-29137baf224d', 'xmin': 0.8856992021497999, 'ymin': 0.05355129696611289, 'xmax': 0.999937441988398, 'ymax': 0.2888982005886864, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}]}
# ...
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/a740d56c-c050-4077-813a-b162e4d644fc.mla {'version': 2, 'uuid': 'a740d56c-c050-4077-813a-b162e4d644fc', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/10980be74d437ac3e3bf86c416424fbb.jpg', 'mlInfo': None, 'annotations': [{'uuid': '1b082ef7-fe27-4395-adb5-ca164fef1c71', 'xmin': 0.5645, 'ymin': 0.5874, 'xmax': 0.65, 'ymax': 0.6759, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid':
 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'dd13a1c2-d483-4fb7-b116-732df31a40bd', 'xmin': 0.7866, 'ymin': 0.8505, 'xmax': 0.862, 'ymax': 0.9309, 'predict ...
# /Users/iman/ml-datasets/detection_boxes/misc/mla_files/all_checked_filtered/26952b54-4293-48c2-8169-bb73d0debf78.mla {'version': 2, 'uuid': '26952b54-4293-48c2-8169-bb73d0debf78', 'url': 'https://storage.googleapis.com/core-345-assets/ml_store_images/c70b359b5bca6846f474d2c9b9d40090.jpg', 'mlInfo': None, 'annotations': [{'uuid': '9c67f32e-0bd5-4cd3-8efb-c7e3e2cce5c8', 'xmin': 0.3819, 'ymin': 0.3477, 'xmax': 0.623, 'ymax': 0.5893, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '9c310302-9d37-448e-bf99-b217ae01ac98', 'xmin': 0.1329, 'ymin': 0, 'xmax': 0.399, 'ymax': 0.2753, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '4da9cba8-cf14-482e-894d-923dd17e4ccb', 'xmin': 0.4037, 'ymin': 0.0005, 'xmax': 0.661, 'ymax': 0.2772, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '356de041-b601-450a-ae5a-8b4aa0903a3b', 'xmin': 0.6388, 'ymin': 0.6464, 'xmax': 0.88, 'ymax': 0.8635, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '157607e6-753a-4c6c-9804-a3f55e935a28', 'xmin': 0.6325, 'ymin': 0.3458, 'xmax': 0.877, 'ymax': 0.59, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'ea83e303-0ad7-42c8-8177-89f3b7d35080', 'xmin': 0.1578, 'ymin': 0.6374, 'xmax': 0.391, 'ymax': 0.8666, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'e766767b-c830-4a82-8446-c809ab6d6281', 'xmin': 0.6621, 'ymin': 0.0003, 'xmax': 0.917, 'ymax': 0.2774, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'c076ecef-e964-4a76-9c8f-e18eb025c4e5', 'xmin': 0.1656, 'ymin': 0.3741, 'xmax': 0.369, 'ymax': 0.5898, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '09ac818c-1b7f-402c-be66-714fd12aca2b', 'xmin': 0.399, 'ymin': 0.6464, 'xmax': 0.632, 'ymax': 0.8659, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '0219ca19-67d3-4b2b-8964-11c86b670112', 'xmin': -0.00429638729044144, 'ymin': 0.3726657425560429, 'xmax': 0.16307591758936518, 'ymax': 0.5900624586141829, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': 'b05ff055-29d3-4377-afa5-8f8f1bb2f50f', 'xmin': 0.0010170192136793946, 'ymin': 0.6459074865924207, 'xmax': 0.15510580783318384, 'ymax': 0.8672931332204347, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '2d98b503-79d3-4737-a947-2dc1eca9f2e9', 'xmin': -0.00429638729044144, 'ymin': 0.0016951995577490454, 'xmax': 0.13916558832082138, 'ymax': 0.27094801302425264, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}, {'uuid': '148d6941-0f85-4244-be57-79060278292f', 'xmin': 0.8856992021497999, 'ymin': 0.3367653674271758, 'xmax': 0.9999374419883982, 'ymax': 0.59205692389912, 'predictions': [], 'selectedReference': None, 'annotationType': 'product'}]}

# %%
len(annotations)
# Out:
# 130

# %%
training_dir
# Out:
# PosixPath('/Users/iman/ml-datasets/detection_boxes/training_data')

# %%
json.dump(annotations, open(Path("/Users/iman/ml-datasets/detection_boxes/vq_boxes/training_data") / "annotations_1.json", "w"), indent=4)
